# %% [markdown]
# (0,5 pkt)
#
# Co ta funkcja wypisze i dlaczego?
#
# Napisz odpowiedź w postaci dokumentacji funkcji!

# %%
def complicated(): #definujemy funkcje complicated
    x = 5 # zmienna x o wartosci 5, zasięg na cała funkcje complicated
    def f1(): #definujemy wewnętrzną funkcje f1
        def f2(): print(x) #definujemy zagnieżdżoną w f1 funkcję f2, która wypisuje zmienną x
        x = 6 # zmienna lokalna o wartości 6 zasłania zmienną z compliacted, funkcja f2 też jej używa
        f2() # wywołanie f2, próba odwołania do zmiennej lokalnej x w f1, wypisze 6
        x = 7 # zmiana wartości zmiennej lokalnej na 7, zasłania zmienną x
        def f3(): x = 8 # nowa zagnieżdżona funkcja f3, zmienna lokalna o wartości 8, nie ma wpływu, bo to tylko wewnatrz f3
        f3() # wywołanie f3
        f2() # wywołanie f2, wypisze 7, lokalna dla f3 nie ma wplywu
    f1() # wywołanie f1

complicated()
# Out:
# 6
# 7
