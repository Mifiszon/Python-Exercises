# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def info(self):
        print(f"{self.title} — {self.author}")

class Library:
    def __init__(self, name):
        self.name = name
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print(f"Książka {book.title} dodana pomyślnie.")
        
    def show_books(self):
        if self.books:
            print("\nKsiążki w",self.name,":")
            for book in self.books:
                book.info()
        else:
            print("Brak książek")

b = Book("Harry Potter i więzień Azkabanu", "J.K.Rowling")
l = Library("Biblioteka Jagiellońska")
l.add_book(b)
l.show_books()
# Out:
# Książka Harry Potter i więzień Azkabanu dodana pomyślnie.
#
# Książki w Biblioteka Jagiellońska :
# Harry Potter i więzień Azkabanu — J.K.Rowling
