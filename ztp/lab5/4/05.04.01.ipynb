# %% [markdown]
# ### Pakiet „pliki”
#
# Proszę utworzyć katalog `pliki` z plikami:
#
# - `__init__.py`
# - `czytaj.py` (funkcja odczytu pliku)
# - `pisz.py` (funkcja zapisu do pliku)
#
#
# Proszę napisać skrypt `main.py`, który zaimportuje te funkcje i umożliwi użytkownikowi zapis i odczyt tekstu z pliku.

# %%
# %run main1.py
# Out:
# Podaj tekst do zapisania:
# >  wtiom
# Zapisano do pliku
#
# Zawartość pliku:
# wtiom
