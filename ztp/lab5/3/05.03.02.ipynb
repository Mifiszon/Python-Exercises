# %% [markdown]
# Proszę przygotować moduł `matematyka.py` z funkcjami:
# - srednia(lista_liczb),
# - wariancja(lista_liczb).
#
# Proszę dodać docstringi do każdej funkcji i wyświetlić ich treść poleceniem help().

# %%
from matematyka import *

help(srednia)
help(wariancja)

list = [4,-3,2]
print(srednia(list))
print(wariancja(list))
# Out:
# Help on function srednia in module matematyka:
#
# srednia(lista_liczb)
#     Zwraca średnią arytemtyczną dowolnej listy liczb.
#
# Help on function wariancja in module matematyka:
#
# wariancja(lista_liczb)
#     Zwraca wariancję dowolnej listy liczb.
#
# 1.0
# 8.666666666666666
