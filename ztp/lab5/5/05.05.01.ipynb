# %% [markdown]
# Proszę przygotować mały projekt w strukturze:
# ```
# notatki/
# │
# ├── data/
# │   └── notatki.json
# │
# ├── core/
# │   ├── __init__.py
# │   ├── pliki.py
# │   └── notatnik.py
# │
# └── main.py
# ```
#
# Wymagania:
#
# - pliki.py – funkcje do zapisu/odczytu JSON,
# - notatnik.py – funkcje dodawania, wyszukiwania i usuwania notatek,
# - main.py – prosty interfejs tekstowy (menu),
# po uruchomieniu użytkownik może dodawać i przeglądać notatki.

# %%
# %run notatki/main.py
# Out:
# === NOTATNIK ===
# 1. Dodaj notatkę
# 2. Pokaż notatki
# 3. Usuń notatkę
# 0. Wyjście
# Wybierz opcję:  1
# Wpisz treść notatki:  witom
# === NOTATNIK ===
# 1. Dodaj notatkę
# 2. Pokaż notatki
# 3. Usuń notatkę
# 0. Wyjście
# Wybierz opcję:  2
# 1. witom
#
# === NOTATNIK ===
# 1. Dodaj notatkę
# 2. Pokaż notatki
# 3. Usuń notatkę
# 0. Wyjście
