# %% [markdown]
# Proszę napisać program, który:
# - wyświetli wszystkie pliki .ipynb w bieżącym katalogu,
# - dla każdego pliku poda jego rozmiar w bajtach.
#
# Proszę użyć modułu pathlib.

# %%
from pathlib import Path
import os

folder = Path(".")
for file in folder.glob("*.ipynb"):
    size = os.path.getsize(file)
    print(f" {file.name} - {size}B")
# Out:
#  05.02.02.ipynb - 1476B
#  05.02.01.ipynb - 2124B
#  05.02.03.ipynb - 1338B
