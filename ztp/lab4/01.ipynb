# %% [markdown]
# Proszę zdefiniować funkcję powitaj(), która wypisze w konsoli tekst.
# Następnie przypisać tę funkcję do zmiennej f i wywołać ją przez f().

# %%
def powitaj():
    print("tekst")

f = powitaj
f()
# Out:
# tekst
