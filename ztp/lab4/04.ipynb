# %% [markdown]
# Proszę wykorzystać map, filter oraz reduce do operacji na liście numbers = [1, 2, 3, 4, 5, 6]:
#
# - za pomocą map proszę utworzyć listę kwadratów.
# - za pomocą filter proszę wybrać liczby parzyste.
# - za pomocą reduce (z modułu functools) proszę obliczyć sumę wszystkich elementów.

# %%
numbers = [1, 2, 3, 4, 5, 6]

m = map(lambda x: x**2, numbers)
print(f"lista kwadratów:",list(m))

f = filter(lambda x: x % 2 == 0, numbers)
print(f"liczby parzyste:", list(f))

r = functools.reduce(lambda x, y : x+y, numbers)
print(f"suma liczb:",r)
# Out:
# lista kwadratów: [1, 4, 9, 16, 25, 36]
# liczby parzyste: [2, 4, 6]
# suma liczb: 21
