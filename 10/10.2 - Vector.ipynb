# %% [markdown]
# Proszę dodać do klasy _Vector_ metodę realizującą iloczyn skalarny przy użyciu operatora mnożenia.
#
# ```
# # Przykład działania poprawnego rozwiązania.
# ```
#
# ```
# v1 = lab11.Vector(0, 1, 0)
# ```
#
# ```
# v2 = lab11.Vector(3, 5, 3)
# ```
#
# ```
# v1 * v2
# ```
#
# ```
# # 5.0
# ```
#
# Proszę dodać do klasy _Vector_ metodę norm zwracającą normę wektora, czyli jego długość.
#
# ```
# # Przykład działania poprawnego rozwiązania.
# ```
#
# ```
# v1.norm()
# ```
#
# ```
# # 1.0
# ```
#
# ```
# v2.norm()
# ```
#
# ```
# # 6.557438524302
# ```
#
# Proszę dodać do klasy _Vector_ metodę ___bool\___, sprawdzającą, czy norma jest niezerowa. Jaki efekt ma dodanie tej metody? Sprawdź w dokumentacji! (https://docs.python.org/3/reference/datamodel.html#object.\__bool\__)

# %%
import math

class Vector:
    "Wektor w trójwymiarowej przestrzeni euklidesowej."
    def __init__(self, x, y, z):
        self.x = float(x)
        self.y = float(y)
        self.z = float(z)

    def __repr__(self):
        return '[%.2f, %.2f, %.2f]' % (self.x, self.y, self.z)

    def __add__(self, vec):
        "suma: self + vec"
        return Vector(self.x + vec.x, self.y + vec.y, self.z + vec.z)

    def __eq__(self, vec):
        return self.x == vec.x and self.y == vec.y and self.z == vec.z

    def __ne__(self, vec):
        return not self == vec

    def __mul__(self, vec):
        return self.x * vec.x + self.y * vec.y + self.z * vec.z

    def norm(self):
        return math.sqrt((self.x ** 2)+(self.y ** 2)+(self.z ** 2))

    def _bool_(self):
        if (self.x == 0 and self.y == 0 and self.z == 0):
            return False
        else:
            return True
        

v1 = Vector(0, 1, 0)
v2 = Vector(3, 5, 3)
v3 = Vector(0, 0, 0)
print(v1 * v2)
print(v1.norm())
print(v2.norm())
print(v2._bool_())
print(v3._bool_())
v1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 36
#      32         else:
#      33             return True
# ---> 36 v1 = lab11.Vector(0, 1, 0)
#      37 v2 = lab11.Vector(3, 5, 3)
#      38 v3 = Vector(0, 0, 0)
#
# NameError: name 'lab11' is not defined
